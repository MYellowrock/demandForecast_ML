# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import ElasticNet
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
import time

df = pd.read_excel("satisverileri.xlsx")
df.dropna(inplace=True)

X = df.drop(["Sales"], axis=1)
y = df["Sales"]

start_time = time.time()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

df_model = ElasticNet().fit(X_train, y_train)
y_pred = df_model.predict(X_test)

r2Score = r2_score(y_test, y_pred)
meanAbsScore = mean_absolute_error(y_test, y_pred)
meanSqScore = mean_squared_error(y_test, y_pred)
MAPE = mean_absolute_percentage_error(y_test, y_pred)

end_time = time.time()

print("R2:" + str(r2Score))
print("Mean Absolute Error:" + str(meanAbsScore))
print("Mean Squared Error:" + str(meanSqScore))
print("MAPE:" + str(MAPE))
elapsed_time = end_time - start_time
print("Elapsed Time: ", elapsed_time, " seconds")
# Out:
# R2:0.46447051704777165
# Mean Absolute Error:653.6757584668072
# Mean Squared Error:725383.9091103588
# MAPE:0.7413041695321949
# Elapsed Time:  0.0036344528198242188  seconds

# %%
# K-fold

import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.linear_model import ElasticNet
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
import time

df = pd.read_excel("satisverileri.xlsx")
df.dropna(inplace=True)

X = df.drop(["Sales"], axis = 1)
y = df["Sales"]

start_time = time.time()

n_folds = 10
kf = KFold(n_splits=n_folds, shuffle=True)

r2_scores = []
mae_scores = []
mse_scores = []
mape_scores = []
elapsed_times = []

for train_idx, test_idx in kf.split(X):
    X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]
    
    model = ElasticNet().fit(X_train, y_train)
    y_pred = model.predict(X_test)
    r2Score = r2_score(y_test, y_pred)
    meanAbsScore = mean_absolute_error(y_test, y_pred)
    meanSqScore = mean_squared_error(y_test, y_pred)
    MAPE = mean_absolute_percentage_error(y_test, y_pred)
    
    r2_scores.append(r2Score)
    mae_scores.append(meanAbsScore)
    mse_scores.append(meanSqScore)
    mape_scores.append(MAPE)
    

mean_r2 = np.mean(r2_scores)
mean_mae = np.mean(mae_scores)
mean_mse = np.mean(mse_scores)
mean_mape = np.mean(mape_scores)

end_time = time.time()

print("R2 Scores:", mean_r2)
print("Mean Absolute Error Scores:", mean_mae)
print("Mean Squared Error Scores:", mean_mse)
print("MAPE Scores:", mean_mape)

elapsed_time = end_time - start_time
print("Elapsed Time:", elapsed_time, "seconds")
# Out:
# R2 Scores: 0.46540895594875
# Mean Absolute Error Scores: 702.2625384782389
# Mean Squared Error Scores: 776120.5335011131
# MAPE Scores: 0.6245782574141944
# Elapsed Time: 0.03032684326171875 seconds

# %%
# K-fold and Parameter Optimizations

import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.linear_model import ElasticNet
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
import time

df = pd.read_excel("satisverileri.xlsx")
df.dropna(inplace=True)

X = df.drop(["Sales"], axis=1)
y = df["Sales"]

n_folds = 10
kf = KFold(n_splits=n_folds, shuffle=True)

alpha_values = np.arange(0, 1001, 1)
iteration_values = [100, 1000, 10000, 100000]

max_mean_r2 = -np.inf
best_alpha = -1
best_iteration = -1

start_time = time.time()

for alpha in alpha_values:
    for iteration in iteration_values:

        r2_scores = []
        mae_scores = []
        mse_scores = []
        mape_scores = []

        for train_idx, test_idx in kf.split(X):
            X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
            y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

            model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
            y_pred = model.predict(X_test)
            r2Score = r2_score(y_test, y_pred)
            meanAbsScore = mean_absolute_error(y_test, y_pred)
            meanSqScore = mean_squared_error(y_test, y_pred)
            MAPE = mean_absolute_percentage_error(y_test, y_pred)

            r2_scores.append(r2Score)
            mae_scores.append(meanAbsScore)
            mse_scores.append(meanSqScore)
            mape_scores.append(MAPE)

        mean_r2 = np.mean(r2_scores)

        if mean_r2 > max_mean_r2:
            max_mean_r2 = mean_r2
            best_alpha = alpha
            best_iteration = iteration

        
end_time = time.time()
elapsed_time = end_time - start_time

print("Elapsed Time:", elapsed_time, "seconds")
print("Best Alpha:", best_alpha)
print("Best Iteration:", best_iteration)
print("Max Mean R2 Score:", max_mean_r2)
# Out:
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 96673227.57179233, tolerance: 53360.32142853189
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 100344544.33050314, tolerance: 52209.19212553188
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 98919427.8307949, tolerance: 52006.054615691304
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 100079471.87448525, tolerance: 51958.8361938
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93062895.0690557, tolerance: 49519.98890851157
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 95304167.32501122, tolerance: 50203.12460260116
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 97495531.17016727, tolerance: 52708.7400723266
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 98355985.80410035, tolerance: 52627.89054460983
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 98791932.61885725, tolerance: 52394.242388497114
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 96261057.79277027, tolerance: 50858.311751781075
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 94484451.15478067, tolerance: 49809.34958731449
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 99043986.28291938, tolerance: 53220.5912345971
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 98059271.0568253, tolerance: 50831.315141140585
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 91941142.2432499, tolerance: 50374.15482492754
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 97624858.07498828, tolerance: 53257.63997545159
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 96491550.6996115, tolerance: 51296.489585914016
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 99999516.77596824, tolerance: 53085.30367875722
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 97867561.62756318, tolerance: 50666.33857395955
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 102196690.61201075, tolerance: 53282.87717656432
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 97715376.24044836, tolerance: 52136.435142951595
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 100163000.04006502, tolerance: 50935.93742785797
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 103552874.44130719, tolerance: 52200.7306523145
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93106326.58973256, tolerance: 52163.939658043484
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 92628189.65430713, tolerance: 52276.61806135797
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 94922152.64977807, tolerance: 50537.39945316835
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93039061.55397318, tolerance: 50157.19040660767
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 97747720.07275164, tolerance: 50775.18427035044
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 101344931.99487993, tolerance: 53289.09780352601
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 98053563.09278041, tolerance: 52275.643269002896
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 100992973.94014725, tolerance: 53310.634272095376
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 99876929.40276942, tolerance: 51228.35209243044
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93692141.82628703, tolerance: 49883.82549122754
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 98043852.27443317, tolerance: 53545.75539972754
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 92836142.44540441, tolerance: 48873.93207632174
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 94730835.0387373, tolerance: 52544.0591190029
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 98069912.20885156, tolerance: 51975.37614606937
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 98611737.92582949, tolerance: 51334.63618790463
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 101359320.32824883, tolerance: 52531.128159541186
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 100205113.41634592, tolerance: 52387.899510433526
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\AppData\Local\Temp/ipykernel_12312/51895058.py:40: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model = ElasticNet(alpha=alpha, max_iter=iteration).fit(X_train, y_train)
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\Murat\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 98473845.82281332, tolerance: 53661.79719757226
#   model = cd_fast.enet_coordinate_descent(
# Elapsed Time: 116.01654171943665 seconds
# Best Alpha: 0
# Best Iteration: 10000
# Max Mean R2 Score: 0.5900275911998475
